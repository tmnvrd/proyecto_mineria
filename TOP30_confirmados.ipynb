# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Anexos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
#from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
#from scipy.stats import kurtosis, skew
#from sklearn.model_selection import train_test_split
#from sklearn.svm import SVC
#from sklearn.metrics import classification_report, classification, accuracy_score
#from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV
#from sklearn.neural_network import MLPClassifier
#from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### VISUALIZACIÓN DE DATASETS

# %% [markdown]
# #### 1) time_series_covid_19_confirmed

# %%
#Si al exportar los datos del git no tienen la carpeta COVID-19, correr path como: csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
datos_global_confirmed = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv',  sep=',')
datos_global_confirmed.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/13/20  4/14/20  4/15/20  4/16/20  \
# 0        0        0        0  ...      665      714      784      840
# 1        0        0        0  ...      467      475      494      518
# 2        0        0        0  ...     1983     2070     2160     2268
# 3        0        0        0  ...      646      659      673      673
# 4        0        0        0  ...       19       19       19       19
#
#    4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# ...

# %% [markdown]
# #### 2) time_series_covid_19_deaths

# %%
datos_global_deaths = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv',  sep=',')
datos_global_deaths.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/13/20  4/14/20  4/15/20  4/16/20  \
# 0        0        0        0  ...       21       23       25       30
# 1        0        0        0  ...       23       24       25       26
# 2        0        0        0  ...      313      326      336      348
# 3        0        0        0  ...       29       31       33       33
# 4        0        0        0  ...        2        2        2        2
#
#    4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# ...

# %% [markdown]
# #### 3) time_series_covid_19_recovered

# %%
datos_global_recovered = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv',  sep=',')
datos_global_recovered.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/13/20  4/14/20  4/15/20  4/16/20  \
# 0        0        0        0  ...       32       40       43       54
# 1        0        0        0  ...      232      248      251      277
# 2        0        0        0  ...      601      691      708      783
# 3        0        0        0  ...      128      128      169      169
# 4        0        0        0  ...        4        5        5        5
#
#    4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# ...

# %% [markdown]
# #### 4) countriesWorld

# %%
datos_countriesWorld = pd.read_excel('countriesWorld_2.xlsx',  sheet_name='final')
datos_countriesWorld.head()
# Out:
#   Country/Region Pop. Density (per sq. mi.)  GDP ($ per capita) Literacy (%)  \
# 0    Afghanistan                       48,0               700.0         36,0
# 1        Albania                      124,6              4500.0         86,5
# 2        Algeria                       13,8              6000.0         70,0
# 3        Andorra                      152,1             19000.0        100,0
# 4         Angola                        9,7              1900.0         42,0
#
#   Birthrate Deathrate  Population
# 0      46,6     20,34  31056997.0
# 1     15,11      5,22   3581655.0
# 2     17,14      4,61  32930091.0
# 3      8,71      6,25     71201.0
# 4     45,11      24,2  12127071.0

# %%
datos_countriesWorld.shape
# Out:
# (185, 7)

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### UNIÓN DE DATASETS

# %%
#Nombres de las columnas del nuevo dataset, union de series de tiempo + variables del pais
lista =list(datos_global_confirmed.columns)[1:]
lista_countries =list(datos_countriesWorld.columns)
for i in range(len(lista_countries)-1):
    lista.append(lista_countries[i+1])

# %%
#Nuevo dataset, donde los tres primeros datos corresponden al nombre_pais, lat y long
# de la columna 4 al 95 son los muertos del 22/1/20 al 22/4/20
# de la columna 96 corresponde a las variables de cada pais, ej: GDP, Population
full_confirmed = pd.DataFrame(columns=lista)

myset = set(datos_global_confirmed['Country/Region'])
i=0
for name in list(myset):
    full_confirmed.loc[i,:3] = datos_global_confirmed[(datos_global_confirmed['Country/Region']==name)].iloc[0,1:4]
    full_confirmed.loc[i,3:95] = (datos_global_confirmed[(datos_global_confirmed['Country/Region']==name)].iloc[:,4:]).sum(axis=0)
    full_confirmed.loc[i,95:] = datos_countriesWorld[(datos_countriesWorld['Country/Region']==name)].iloc[0,1:]
    i += 1

# %%
# Visualizacion de datos para Chile
full_confirmed[(full_confirmed['Country/Region']=='Chile')]
# Out:
#    Country/Region      Lat    Long 1/22/20 1/23/20 1/24/20 1/25/20 1/26/20  \
# 45          Chile -35.6751 -71.543       0       0       0       0       0
#
#    1/27/20 1/28/20  ... 4/19/20 4/20/20 4/21/20 4/22/20  \
# 45       0       0  ...   10088   10507   10832   11296
#
#    Pop. Density (per sq. mi.) GDP ($ per capita) Literacy (%) Birthrate  \
# 45                       21,3               9900         96,2     15,23
#
#    Deathrate   Population
# 45      5,81  1.61342e+07
#
# [1 rows x 101 columns]

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### ELIMINACIÓN DATOS NaN O VACÍOS

# %%
# BORRAR LOS NA
full_confirmed.dropna(axis=0, inplace=True)
full_confirmed = full_confirmed.reset_index(drop=True)

# %%
#Dimension del dataframe resultante
full_confirmed.shape
# Out:
# (170, 101)

# %%
#Confirmacion de datos NaN
full_confirmed.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### NORMALIZACION DE CASOS CONFIRMADOS

# %%
#Se ordenan los paises alfabeticamente
full_confirmed = full_confirmed.sort_values('Country/Region')

# %%
full_confirmed.iloc[143]
full_confirmed.head()
# Out:
#     Country/Region      Lat     Long 1/22/20 1/23/20 1/24/20 1/25/20 1/26/20  \
# 21     Afghanistan       33       65       0       0       0       0       0
# 86         Albania  41.1533  20.1683       0       0       0       0       0
# 43         Algeria  28.0339   1.6596       0       0       0       0       0
# 149        Andorra  42.5063   1.5218       0       0       0       0       0
# 31          Angola -11.2027  17.8739       0       0       0       0       0
#
#     1/27/20 1/28/20  ... 4/19/20 4/20/20 4/21/20 4/22/20  \
# 21        0       0  ...     996    1026    1092    1176
# 86        0       0  ...     562     584     609     634
# 43        0       0  ...    2629    2718    2811    2910
# 149       0       0  ...     713     717     717     723
# 31        0       0  ...      24      24      24      25
#
#     Pop. Density (per sq. mi.) GDP ($ per capita) Literacy (%) Birthrate  \
# 21                        48,0                700         36,0      46,6
# ...

# %%
#Vector que contiene los porcentajes de contagiados 
porcentajeConfirmados = pd.DataFrame((100*full_confirmed.iloc[:,94])/full_confirmed.iloc[:,100],columns=['Porcentaje'])
porcentajeConfirmados
# Out:
#       Porcentaje
# 21    0.00378659
# 86     0.0177013
# 43     0.0088369
# 149      1.01544
# 31    0.00020615
# ..           ...
# 73   0.000317524
# 81    0.00219774
# 17   4.66066e-06
# 49   0.000643366
# 53   0.000228818
#
# [170 rows x 1 columns]

# %%
#Dataframe de los confirmados en porcentaje, con nombre_pais + porcentaje
confirmadosNormalizados = pd.concat([full_confirmed.iloc[:,0],porcentajeConfirmados], axis=1)
confirmadosNormalizados
# Out:
#      Country/Region   Porcentaje
# 21      Afghanistan   0.00378659
# 86          Albania    0.0177013
# 43          Algeria    0.0088369
# 149         Andorra      1.01544
# 31           Angola   0.00020615
# ..              ...          ...
# 73          Vietnam  0.000317524
# 81   Western Sahara   0.00219774
# 17            Yemen  4.66066e-06
# 49           Zambia  0.000643366
# 53         Zimbabwe  0.000228818
#
# [170 rows x 2 columns]

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### TOP 30 CASOS CONFIRMADOS

# %%
#Extraccion de los primeros 30 paises mas contagiados en porcentaje
top30_norm = confirmadosNormalizados.sort_values('Porcentaje',ascending=False).iloc[:29,:]
top30_norm
# Out:
#            Country/Region Porcentaje
# 40             San Marino    1.66832
# 149               Andorra    1.01544
# 115                 Qatar   0.806565
# 26             Luxembourg   0.770215
# 122               Iceland   0.596216
# 67                  Spain   0.515842
# 1                 Ireland    0.41039
# 32                Belgium   0.403591
# 130           Switzerland   0.375708
# 45                  Italy   0.322236
# 97   United Arab Emirates   0.316516
# 14                Bahrain   0.290158
# 139                Monaco   0.288849
# 88                     US   0.281577
# 87                 France   0.258106
# 156         Liechtenstein   0.238326
# 84                 Israel   0.228239
# 119             Singapore   0.225749
# 59         United Kingdom   0.222141
# 58            Netherlands   0.212425
# 51               Portugal   0.207263
# 22               Djibouti   0.200193
# 111               Germany   0.182776
# 80                Austria    0.18217
# ...

# %%
#Extraccion de los 30 paises con mas confirmados, sin normalizar
confirmadosSinNormalizados = pd.concat([full_confirmed.iloc[:,0],full_confirmed.iloc[:,94]], axis=1)
top30_NO_norm = confirmadosSinNormalizados.sort_values('4/22/20',ascending=False).iloc[:29,:]
top30_NO_norm
confirmadosSinNormalizados.head()
# Out:
#     Country/Region 4/22/20
# 21     Afghanistan    1176
# 86         Albania     634
# 43         Algeria    2910
# 149        Andorra     723
# 31          Angola      25

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %%
#Scatter plots

new1=confirmadosSinNormalizados.sort_values('4/22/20',ascending=False).iloc[3:96,:]
new2=confirmadosNormalizados.sort_values('Porcentaje',ascending=False).iloc[3:96,:]

# %%
#Scatter plots para confirmados con normalizar
# %matplotlib inline
plt.figure(1)
for i in new1['Country/Region'].values:
        jei=full_confirmed[(full_confirmed['Country/Region']==i)]['Population'].values
        #jei = np.char.replace(jei[0], ',', '.')
        if i=="Chile":
            plt.plot(jei,float(new1[new1['Country/Region']==i]['4/22/20']),'ro',label="Chile")
        else:
            plt.plot(jei,float(new1[new1['Country/Region']==i]['4/22/20']),'bo')        
plt.title('Poblacion vs contagiados')
plt.yscale('log')
plt.xscale('log')
plt.xlabel("Poblacion")
plt.ylabel("Contagiados")
plt.legend()
plt.show()
plt.figure(2)
for i in new1['Country/Region'].values:
        jei=full_confirmed[(full_confirmed['Country/Region']==i)]['GDP ($ per capita)'].values
        #jei = np.char.replace(jei[0], ',', '.')
        if i=="Chile":
            plt.plot(jei,float(new1[new1['Country/Region']==i]['4/22/20']),'ro', label="Chile")
        else:
            plt.plot(jei,float(new1[new1['Country/Region']==i]['4/22/20']),'bo')
plt.title('GDP ($ per capita) vs contagiados')
plt.yscale('log')
plt.xscale('log')
plt.xlabel("GPD [USD/capita]")
plt.ylabel("Contagiados")
plt.legend()
plt.figure(3)
plt.show()
for i in new1['Country/Region'].values:
        jei=full_confirmed[(full_confirmed['Country/Region']==i)]['Literacy (%)'].values
        #jei = np.char.replace(jei[0], ',', '.')
        if i=="Chile":
            plt.plot(jei,float(new1[new1['Country/Region']==i]['4/22/20']),'ro', label="Chile")
        else:
            plt.plot(jei,float(new1[new1['Country/Region']==i]['4/22/20']),'bo')
plt.title('Literacy (%) vs contagiados')
plt.yscale('log')
plt.xscale('log')
plt.xlabel("Alfabetismo [%]")
plt.ylabel("Contagiados")
plt.legend()
plt.figure(4)
plt.show()
for i in new1['Country/Region'].values:
        jei=full_confirmed[(full_confirmed['Country/Region']==i)]['Pop. Density (per sq. mi.)'].values
        #jei = np.char.replace(jei[0], ',', '.')
        if i=="Chile":
            plt.plot(jei,float(new1[new1['Country/Region']==i]['4/22/20']),'ro', label="Chile")
        else:
            plt.plot(jei,float(new1[new1['Country/Region']==i]['4/22/20']),'bo')
plt.title('Pop. Density (per sq. mi.) vs contagiados')
plt.yscale('log')
plt.xscale('log')
plt.xlabel("Densidad Poblacional [sq. mi]")
plt.ylabel("Contagiados")
plt.legend()
plt.show()

# %%
#Scatter plots normalizados
# %matplotlib inline
plt.figure(1)
for i in new2['Country/Region'].values:
        jei=full_confirmed[(full_confirmed['Country/Region']==i)]['Population'].values
        #jei = np.char.replace(jei[0], ',', '.')
        if i=="Chile":
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'ro',label="Chile")
        else:
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'bo')        
plt.title('population vs contagiadosnormalizados')
plt.yscale('log')
plt.xscale('log')
plt.xlabel("Poblacion")
plt.ylabel("Contagiados")
plt.legend()
plt.show()
plt.figure(2)
for i in new2['Country/Region'].values:
        jei=full_confirmed[(full_confirmed['Country/Region']==i)]['GDP ($ per capita)'].values
        #jei = np.char.replace(jei[0], ',', '.')
        if i=="Chile":
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'ro', label="Chile")
        else:
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'bo')
plt.title('GDP ($ per capita) vs contagiadosnormalizados')
plt.yscale('log')
plt.xscale('log')
plt.xlabel("GPD [USD/capita]")
plt.ylabel("Contagiados")
plt.legend()
plt.figure(3)
plt.show()
for i in new2['Country/Region'].values:
        jei=full_confirmed[(full_confirmed['Country/Region']==i)]['Literacy (%)'].values
        #jei = np.char.replace(jei[0], ',', '.')
        if i=="Chile":
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'ro', label="Chile")
        else:
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'bo')
plt.title('Literacy (%) vs contagiadosnormalizados')
plt.yscale('log')
plt.xscale('log')
plt.xlabel("Alfabetismo [%]")
plt.ylabel("Contagiados")
plt.legend()
plt.figure(4)
plt.show()
for i in new2['Country/Region'].values:
        jei=full_confirmed[(full_confirmed['Country/Region']==i)]['Pop. Density (per sq. mi.)'].values
        #jei = np.char.replace(jei[0], ',', '.')
        if i=="Chile":
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'ro', label="Chile")
        else:
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'bo')
plt.title('Pop. Density (per sq. mi.) vs contagiadosnormalizados')
plt.yscale('log')
plt.xscale('log')
plt.xlabel("Densidad Poblacional [sq. mi]")
plt.ylabel("Contagiados")
plt.legend()
plt.show()

# %% [markdown]
# ### CURVAS DE TIEMPO: TOP 30 CONFIRMADOS NORMALIZADOS

# %%
#Lista con los 10 paises con mas contagiados segun porcentaje
top30_norm_lista = top30_norm['Country/Region'].unique()
top30_norm_lista[:10]
# Out:
# array(['San Marino', 'Andorra', 'Qatar', 'Luxembourg', 'Iceland', 'Spain',
#        'Ireland', 'Belgium', 'Switzerland', 'Italy'], dtype=object)

# %%
#Nombres de las columnas del nuevo dataset, nombre_pais + union de series de tiempo
lista_top30_norm =['Country/Region']
lista_fechas =list(datos_global_confirmed.columns)[4:]
for i in range(len(lista_fechas)):
    lista_top30_norm.append(lista_fechas[i])

# %%
#Los datos del TOP30_normalizados se separan en 2 dataframes por facilidades de plot
# full_confirmed_top30_norm10: Primeros 10 paises del TOP30 normalizados
# full_confirmed_top30_norm20: 20 paises restantes del TOP30 normalizados

#Cada dataframe contiene el nombre del pais en la primera columna
# de la columna 2 al 95 son los muertos del 22/1/20 al 22/4/20

full_confirmed_top30_norm10 = pd.DataFrame(columns=lista_top30_norm)
full_confirmed_top30_norm20 = pd.DataFrame(columns=lista_top30_norm)

myset_confirmed10 = set(top30_norm_lista[:10])
myset_confirmed20 = set(top30_norm_lista[10:])
i=0
for name in list(myset_confirmed10):
    full_confirmed_top30_norm10.loc[i,:1] = name
    full_confirmed_top30_norm10.loc[i,1:] = (100*(datos_global_confirmed[(datos_global_confirmed['Country/Region']==name)].iloc[:,4:]).sum(axis=0))/datos_countriesWorld[(datos_countriesWorld['Country/Region']==name)].iloc[0,6]
    i += 1
for name in list(myset_confirmed20):    
    full_confirmed_top30_norm20.loc[i,:1] = name
    full_confirmed_top30_norm20.loc[i,1:] = (100*(datos_global_confirmed[(datos_global_confirmed['Country/Region']==name)].iloc[:,4:]).sum(axis=0))/datos_countriesWorld[(datos_countriesWorld['Country/Region']==name)].iloc[0,6]
    i += 1

# %%
#se trasponen los datos para que los ejes coicidan en el plot
df10 = full_confirmed_top30_norm10.T
header10 = df10.iloc[0]
df10 = df10[1:]
df10.columns = header10
df10
# Out:
# Country/Region   Ireland San Marino     Spain   Belgium     Qatar  Andorra  \
# 1/22/20                0          0         0         0         0        0
# 1/23/20                0          0         0         0         0        0
# 1/24/20                0          0         0         0         0        0
# 1/25/20                0          0         0         0         0        0
# 1/26/20                0          0         0         0         0        0
# ...                  ...        ...       ...       ...       ...      ...
# 4/18/20         0.363298     1.5555  0.474595   0.35825  0.565646  0.98875
# 4/19/20         0.375434    1.57601  0.491794    0.3709  0.615344  1.00139
# 4/20/20         0.385305    1.57943  0.495596  0.385227  0.679385  1.00701
# 4/21/20         0.394857    1.62729  0.505418  0.394602  0.737893  1.00701
# 4/22/20          0.41039    1.66832  0.515842  0.403591  0.806565  1.01544
#
# Country/Region   Iceland Switzerland     Italy Luxembourg
# ...

# %%
df20 = full_confirmed_top30_norm20.T
header20 = df20.iloc[0]
df20 = df20[1:]
df20.columns = header20

# %% [markdown]
# # ............................................
# #### NORMALIZACIÓN DE DATOS: POR POBLACIÓN

# %%
# Plot del TOP30 normalizado [%], se destacan los primero 10 paises
# %matplotlib notebook
ax = df10.plot(style='*')
df20.plot(ax = ax, style='-')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Confirmados [%]')
plt.title('Casos confirmados a la fecha, para TOP30 normalizado')
plt.legend(df10.columns)
plt.show()
# Out:
# <div id='365a0e6d-7bdc-452b-baeb-e148e202c6b3'></div>

# %%
#Plot detallado del anterior, donde se muestran los primeros 10 paises
# %matplotlib notebook
df10.plot(style='*')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Confirmados [%]')
plt.title('Top 10 de casos de confirmados, para TOP30 normalizado')
plt.legend()
plt.show()
# Out:
# <div id='824ba845-e5ae-4c8d-be3c-6c0346ba4bdc'></div>

# %% [markdown]
# # ..................................................
# #### NORMALIZACIÓN DE DATOS: ESCALA LOGARÍTMICA

# %%
# %matplotlib notebook
ax = df10.plot(style='*')
df20.plot(ax = ax, style='.')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Confirmados [%]')
plt.title('Casos confirmados a la fecha, para TOP30 normalizado')
plt.legend(df10.columns)
plt.yscale('log')
plt.show()
# Out:
# <div id='fa4d059d-7a4c-47f5-9410-19279cc45809'></div>

# %%
# %matplotlib notebook
df10.plot(style='.')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Confirmados [%]')
plt.title('Top 10 de casos de confirmados, para TOP30 normalizado')
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# <div id='f14f5556-b6bb-4f69-963d-29f593597811'></div>

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### CURVAS DE TIEMPO: TOP 30 MUERTOS NO NORMALIZADOS

# %%
#Caso analogo al anterior, donde se toman los paises del TOP30_NO_normalizados. 
#Sin embargo, para que sean comparables los paises estos deben ser normalizados.
#De este modo, se vuelven a crear los datasets.

# %%
#Lista con los 10 paises con mas contagiados sin normalizar
top30_NOnorm_lista = top30_NO_norm['Country/Region'].unique()
top30_NOnorm_lista[:10]
# Out:
# array(['US', 'Spain', 'Italy', 'France', 'Germany', 'United Kingdom',
#        'Turkey', 'Iran', 'China', 'Russia'], dtype=object)

# %%
#Nombres de las columnas del nuevo dataset, nombre_pais + union de series de tiempo
lista_top30_NOnorm =['Country/Region']
lista_fechas =list(datos_global_confirmed.columns)[4:]
for i in range(len(lista_fechas)):
    lista_top30_NOnorm.append(lista_fechas[i])

# %%
#Los datos del TOP30_NO_normalizados se separan en 2 dataframes por facilidades de plot
# full_death_top30_norm10: Primeros 10 paises del TOP30 sin normalizar
# full_death_top30_norm20: 20 paises restantes del TOP30 sin normalizar

#Cada dataframe contiene el nombre del pais en la primera columna
# de la columna 2 al 95 son los muertos del 22/1/20 al 22/4/20

full_confirmed_top30_NOnorm10 = pd.DataFrame(columns=lista_top30_NOnorm)
full_confirmed_top30_NOnorm20 = pd.DataFrame(columns=lista_top30_NOnorm)

myset_confirmed10NO = set(top30_NOnorm_lista[:10])
myset_confirmed20NO = set(top30_NOnorm_lista[10:])
i=0
for name in list(myset_confirmed10NO):
    full_confirmed_top30_NOnorm10.loc[i,:1] = name
    full_confirmed_top30_NOnorm10.loc[i,1:] = (100*(datos_global_confirmed[(datos_global_confirmed['Country/Region']==name)].iloc[:,4:]).sum(axis=0))/datos_countriesWorld[(datos_countriesWorld['Country/Region']==name)].iloc[0,6]
    i += 1
for name in list(myset_confirmed20NO):    
    full_confirmed_top30_NOnorm20.loc[i,:1] = name
    full_confirmed_top30_NOnorm20.loc[i,1:] = (100*(datos_global_confirmed[(datos_global_confirmed['Country/Region']==name)].iloc[:,4:]).sum(axis=0))/datos_countriesWorld[(datos_countriesWorld['Country/Region']==name)].iloc[0,6]
    i += 1

# %%
#se trasponen los datos para que los ejes coicidan en el plot
df10NO = full_confirmed_top30_NOnorm10.T
header10NO = df10NO.iloc[0]
df10NO = df10NO[1:]
df10NO.columns = header10NO
df10NO
# Out:
# Country/Region        China   Germany     Russia     Spain    Turkey  \
# 1/22/20         4.17056e-05         0          0         0         0
# 1/23/20         4.89355e-05         0          0         0         0
# 1/24/20         7.00166e-05         0          0         0         0
# 1/25/20         0.000107004         0          0         0         0
# 1/26/20         0.000157918         0          0         0         0
# ...                     ...       ...        ...       ...       ...
# 4/18/20          0.00637661  0.173912  0.0257485  0.474595  0.116921
# 4/19/20          0.00637798  0.176147  0.0299895  0.491794  0.122569
# 4/20/20          0.00637889  0.178429  0.0329763  0.495596  0.129207
# 4/21/20          0.00638163  0.179916  0.0369247  0.505418  0.135756
# 4/22/20          0.00638278  0.182776   0.040589  0.515842  0.140134
#
# Country/Region United Kingdom       France      Iran     Italy           US
# ...

# %%
df20NO = full_confirmed_top30_NOnorm20.T
header20NO = df20NO.iloc[0]
df20NO = df20NO[1:]
df20NO.columns = header20NO

# %% [markdown]
# # ............................................
# #### NORMALIZACIÓN DE DATOS: POR POBLACIÓN

# %%
# Plot del TOP30 sin normalizar, se destacan los primeros 10 paises
# %matplotlib notebook
ax = df10NO.plot(style='*')
df20NO.plot(ax = ax, style='-')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Confirmados[%]')
plt.title('Casos confirmados a la fecha, para TOP30 sin normalizar')
plt.legend(df10NO.columns)
plt.show()
# Out:
# <div id='c5182fb1-0c64-429d-b8f2-fc7c5018b1f8'></div>

# %%
# %matplotlib notebook
df10NO.plot(style='.')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Confirmados [%]')
plt.title('Top 10 de casos de confirmados, para TOP30 sin normalizar')
plt.legend()
plt.show()
# Out:
# <div id='18e9f105-e7f2-4964-968e-2d32fe2b1b83'></div>

# %% [markdown]
# # ..................................................
# #### NORMALIZACIÓN DE DATOS: ESCALA LOGARÍTMICA

# %%
# %matplotlib notebook
ax = df10NO.plot(style='*')
df20NO.plot(ax = ax, style='.')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Confirmados [%]')
plt.title('Casos confirmados a la fecha, para TOP30 sin normalizar')
plt.legend(df10NO.columns)
plt.yscale('log')
plt.show()
# Out:
# <div id='b0b67252-8a0e-4013-ac40-89489112a799'></div>

# %%
# %matplotlib notebook
df10NO.plot(style='.')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Confirmados [%]')
plt.title('Top 10 de casos de confirmados, para TOP30 sin normalizar')
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# <div id='f2368c5f-6ea0-4bd1-b34e-8c4ca5b1bfb6'></div>
