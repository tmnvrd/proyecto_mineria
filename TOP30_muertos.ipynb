# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Anexos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
#from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
#from scipy.stats import kurtosis, skew
#from sklearn.model_selection import train_test_split
#from sklearn.svm import SVC
#from sklearn.metrics import classification_report, classification, accuracy_score
#from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV
#from sklearn.neural_network import MLPClassifier
#from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### VISUALIZACIÓN DE DATASETS

# %% [markdown]
# #### 1) time_series_covid_19_confirmed

# %%
#Si al exportar los datos del git no tienen la carpeta COVID-19, correr path como: csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
datos_global_confirmed = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv',  sep=',')
datos_global_confirmed.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/13/20  4/14/20  4/15/20  4/16/20  \
# 0        0        0        0  ...      665      714      784      840
# 1        0        0        0  ...      467      475      494      518
# 2        0        0        0  ...     1983     2070     2160     2268
# 3        0        0        0  ...      646      659      673      673
# 4        0        0        0  ...       19       19       19       19
#
#    4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# 0      906      933      996     1026     1092     1176
# 1      539      548      562      584      609      634
# 2     2418     2534     2629     2718     2811     2910
# 3      696      704      713      717      717      723
# 4       19       24       24       24       24       25
#
# [5 rows x 96 columns]

# %% [markdown]
# #### 2) time_series_covid_19_deaths

# %%
datos_global_deaths = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv',  sep=',')
datos_global_deaths.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/13/20  4/14/20  4/15/20  4/16/20  \
# 0        0        0        0  ...       21       23       25       30
# 1        0        0        0  ...       23       24       25       26
# 2        0        0        0  ...      313      326      336      348
# 3        0        0        0  ...       29       31       33       33
# 4        0        0        0  ...        2        2        2        2
#
#    4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# 0       30       30       33       36       36       40
# 1       26       26       26       26       26       27
# 2      364      367      375      384      392      402
# 3       35       35       36       37       37       37
# 4        2        2        2        2        2        2
#
# [5 rows x 96 columns]

# %% [markdown]
# #### 3) time_series_covid_19_recovered

# %%
datos_global_recovered = pd.read_csv('csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv',  sep=',')
datos_global_recovered.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/13/20  4/14/20  4/15/20  4/16/20  \
# 0        0        0        0  ...       32       40       43       54
# 1        0        0        0  ...      232      248      251      277
# 2        0        0        0  ...      601      691      708      783
# 3        0        0        0  ...      128      128      169      169
# 4        0        0        0  ...        4        5        5        5
#
#    4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# 0       99      112      131      135      150      166
# 1      283      302      314      327      345      356
# 2      846      894     1047     1099     1152     1204
# 3      191      205      235      248      282      309
# 4        5        6        6        6        6        6
#
# [5 rows x 96 columns]

# %% [markdown]
# #### 4) countriesWorld

# %%
datos_countriesWorld = pd.read_excel('countriesWorld_2.xlsx',  sheet_name='final')
datos_countriesWorld.head()
# Out:
#   Country/Region  Pop. Density (per sq. mi.)  GDP ($ per capita) Literacy (%)  \
# 0    Afghanistan                        48.0               700.0           36
# 1        Albania                       124.6              4500.0         86.5
# 2        Algeria                        13.8              6000.0           70
# 3        Andorra                       152.1             19000.0          100
# 4         Angola                         9.7              1900.0           42
#
#    Birthrate  Deathrate  Population
# 0      46.60      20.34  31056997.0
# 1      15.11       5.22   3581655.0
# 2      17.14       4.61  32930091.0
# 3       8.71       6.25     71201.0
# 4      45.11      24.20  12127071.0

# %%
datos_countriesWorld.shape
# Out:
# (185, 7)

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### UNIÓN DE DATASETS

# %%
#Nombres de las columnas del nuevo dataset, union de series de tiempo + variables del pais
lista =list(datos_global_deaths.columns)[1:]
lista_countries =list(datos_countriesWorld.columns)
for i in range(len(lista_countries)-1):
    lista.append(lista_countries[i+1])

# %%
#Nuevo dataset, donde los tres primeros datos corresponden al nombre_pais, lat y long
# de la columna 4 al 95 son los muertos del 22/1/20 al 22/4/20
# de la columna 96 corresponde a las variables de cada pais, ej: GDP, Population
full_death = pd.DataFrame(columns=lista)

myset = set(datos_global_deaths['Country/Region'])
i=0
for name in list(myset):
    full_death.loc[i,:3] = datos_global_deaths[(datos_global_deaths['Country/Region']==name)].iloc[0,1:4]
    full_death.loc[i,3:95] = (datos_global_deaths[(datos_global_deaths['Country/Region']==name)].iloc[:,4:]).sum(axis=0)
    full_death.loc[i,95:] = datos_countriesWorld[(datos_countriesWorld['Country/Region']==name)].iloc[0,1:]
    i += 1

# %%
# Visualizacion de datos para Chile
full_death[(full_death['Country/Region']=='Chile')]
# Out:
#    Country/Region      Lat    Long 1/22/20 1/23/20 1/24/20 1/25/20 1/26/20  \
# 39          Chile -35.6751 -71.543       0       0       0       0       0
#
#    1/27/20 1/28/20  ... 4/19/20 4/20/20 4/21/20 4/22/20  \
# 39       0       0  ...     133     139     147     160
#
#    Pop. Density (per sq. mi.) GDP ($ per capita) Literacy (%) Birthrate  \
# 39                       21.3               9900         96.2     15.23
#
#    Deathrate   Population
# 39      5.81  1.61342e+07
#
# [1 rows x 101 columns]

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### ELIMINACIÓN DATOS NaN O VACÍOS

# %%
# BORRAR LOS NA
full_death.dropna(axis=0, inplace=True)
full_death = full_death.reset_index(drop=True)

# %%
#Dimension del dataframe resultante
full_death.shape
# Out:
# (170, 101)

# %%
#Reconfirmacion de datos NaN
full_death.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### NORMALIZACION DE CASOS MUERTOS

# %%
#Se ordenan los paises alfabeticamente
full_death = full_death.sort_values('Country/Region')

# %%
full_death.iloc[143]
# Out:
# Country/Region                      Spain
# Lat                                    40
# Long                                   -4
# 1/22/20                                 0
# 1/23/20                                 0
# 1/24/20                                 0
# 1/25/20                                 0
# 1/26/20                                 0
# 1/27/20                                 0
# 1/28/20                                 0
# 1/29/20                                 0
# 1/30/20                                 0
# 1/31/20                                 0
# 2/1/20                                  0
# 2/2/20                                  0
# 2/3/20                                  0
# 2/4/20                                  0
# 2/5/20                                  0
# 2/6/20                                  0
# 2/7/20                                  0
# 2/8/20                                  0
# 2/9/20                                  0
# 2/10/20                                 0
# 2/11/20                                 0
# 2/12/20                                 0
# 2/13/20                                 0
# 2/14/20                                 0
# 2/15/20                                 0
# 2/16/20                                 0
# 2/17/20                                 0
#                                  ...
# 3/30/20                              7716
# 3/31/20                              8464
# 4/1/20                               9387
# 4/2/20                              10348
# 4/3/20                              11198
# 4/4/20                              11947
# 4/5/20                              12641
# 4/6/20                              13341
# 4/7/20                              14045
# 4/8/20                              14792
# 4/9/20                              15447
# 4/10/20                             16081
# 4/11/20                             16606
# 4/12/20                             17209
# 4/13/20                             17756
# 4/14/20                             18056
# 4/15/20                             18708
# 4/16/20                             19315
# 4/17/20                             20002
# 4/18/20                             20043
# 4/19/20                             20453
# 4/20/20                             20852
# 4/21/20                             21282
# 4/22/20                             21717
# Pop. Density (per sq. mi.)             80
# GDP ($ per capita)                  22000
# Literacy (%)                         97.9
# Birthrate                           10.06
# Deathrate                            9.72
# Population                    4.03978e+07
# Name: 10, Length: 101, dtype: object

# %%
#Vector que contiene los porcentajes de contagiados 
porcentajeMuertos = pd.DataFrame((100*full_death.iloc[:,94])/full_death.iloc[:,100],columns=['Porcentaje'])
porcentajeMuertos
# Out:
#       Porcentaje
# 66   0.000128795
# 12   0.000753841
# 11    0.00122077
# 24     0.0519656
# 108   1.6492e-05
# 136   0.00434103
# 21   0.000380744
# 32   0.000806351
# 91   0.000330634
# 97    0.00622492
# 90   0.000251205
# 141   0.00296277
# 138   0.00100203
# 17   8.14303e-05
# 117   0.00178628
# 162  0.000563489
# 137     0.060333
# 28   0.000695096
# 125  1.27179e-05
# 131            0
# 39   0.000411612
# 96   6.09818e-05
# 119    0.0015451
# 156  0.000263544
# 15   0.000663474
# 79   0.000280516
# 134  1.05524e-05
# 99   1.23608e-05
# 118  0.000237542
# 94             0
# ..           ...
# 14    0.00392967
# 121  9.02594e-05
# 48     0.0001471
# 10     0.0537578
# 127  3.46154e-05
# 129  3.15256e-05
# 72    0.00022773
# 101    0.0214826
# 85      0.020056
# 50   1.58887e-05
# 61   2.60461e-05
# 46   2.67056e-05
# 166  7.58143e-05
# 103  0.000108133
# 5     0.00075058
# 155  0.000373464
# 76    0.00337433
# 7      0.0156217
# 89             0
# 143  0.000372505
# 73    0.00199792
# 126    0.0299476
# 78   0.000349657
# 20   2.56343e-05
# 2    3.88645e-05
# 4              0
# 82             0
# 67             0
# 140  2.60824e-05
# 6    3.26883e-05
#
# [170 rows x 1 columns]

# %%
#Dataframe de los muertos en porcentaje, con nombre_pais + porcentaje
muertosNormalizados = pd.concat([full_death.iloc[:,0],porcentajeMuertos], axis=1)
muertosNormalizados
# Out:
#            Country/Region   Porcentaje
# 66            Afghanistan  0.000128795
# 12                Albania  0.000753841
# 11                Algeria   0.00122077
# 24                Andorra    0.0519656
# 108                Angola   1.6492e-05
# 136   Antigua and Barbuda   0.00434103
# 21              Argentina  0.000380744
# 32                Armenia  0.000806351
# 91              Australia  0.000330634
# 97                Austria   0.00622492
# 90             Azerbaijan  0.000251205
# 141               Bahamas   0.00296277
# 138               Bahrain   0.00100203
# 17             Bangladesh  8.14303e-05
# 117              Barbados   0.00178628
# 162               Belarus  0.000563489
# 137               Belgium     0.060333
# 28                 Belize  0.000695096
# 125                 Benin  1.27179e-05
# 131                Bhutan            0
# 39                Bolivia  0.000411612
# 96               Botswana  6.09818e-05
# 119                Brazil    0.0015451
# 156                Brunei  0.000263544
# 15               Bulgaria  0.000663474
# 79           Burkina Faso  0.000280516
# 134                 Burma  1.05524e-05
# 99                Burundi  1.23608e-05
# 118            Cabo Verde  0.000237542
# 94               Cambodia            0
# ..                    ...          ...
# 14               Slovenia   0.00392967
# 121               Somalia  9.02594e-05
# 48           South Africa    0.0001471
# 10                  Spain    0.0537578
# 127             Sri Lanka  3.46154e-05
# 129                 Sudan  3.15256e-05
# 72               Suriname   0.00022773
# 101                Sweden    0.0214826
# 85            Switzerland     0.020056
# 50                  Syria  1.58887e-05
# 61                Taiwan*  2.60461e-05
# 46               Tanzania  2.67056e-05
# 166              Thailand  7.58143e-05
# 103                  Togo  0.000108133
# 5     Trinidad and Tobago   0.00075058
# 155               Tunisia  0.000373464
# 76                 Turkey   0.00337433
# 7                      US    0.0156217
# 89                 Uganda            0
# 143               Ukraine  0.000372505
# 73   United Arab Emirates   0.00199792
# 126        United Kingdom    0.0299476
# 78                Uruguay  0.000349657
# 20             Uzbekistan  2.56343e-05
# 2               Venezuela  3.88645e-05
# 4                 Vietnam            0
# 82         Western Sahara            0
# 67                  Yemen            0
# 140                Zambia  2.60824e-05
# 6                Zimbabwe  3.26883e-05
#
# [170 rows x 2 columns]

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### TOP 30 CASOS MUERTOS

# %%
#Extraccion de los primeros 30 paises mas muertos en porcentaje
top30_norm = muertosNormalizados.sort_values('Porcentaje',ascending=False).iloc[:29,:]
top30_norm
# Out:
#           Country/Region  Porcentaje
# 47            San Marino    0.136747
# 137              Belgium    0.060333
# 10                 Spain   0.0537578
# 24               Andorra   0.0519656
# 16                 Italy   0.0431507
# 63                France    0.035109
# 126       United Kingdom   0.0299476
# 135          Netherlands   0.0246673
# 101               Sweden   0.0214826
# 85           Switzerland    0.020056
# 55               Ireland   0.0189305
# 1             Luxembourg   0.0168629
# 7                     US   0.0156217
# 8                 Monaco  0.00921857
# 68                  Iran  0.00784848
# 87              Portugal  0.00740156
# 23               Denmark  0.00704502
# 74               Germany  0.00640482
# 26                Canada  0.00626908
# 97               Austria  0.00622492
# 18                Panama  0.00441824
# 136  Antigua and Barbuda  0.00434103
# 56                Norway  0.00405568
# 80               Ecuador  0.00396383
# 14              Slovenia  0.00392967
# 76                Turkey  0.00337433
# 58               Iceland  0.00334015
# 88               Estonia  0.00332243
# 161               Israel  0.00297539

# %%
#Extraccion de los 30 paises con mas muertos, sin normalizar
muertosSinNormalizados = pd.concat([full_death.iloc[:,0],full_death.iloc[:,94]], axis=1)
top30_NO_norm = muertosSinNormalizados.sort_values('4/22/20',ascending=False).iloc[:29,:]
top30_NO_norm
# Out:
#      Country/Region 4/22/20
# 7                US   46622
# 16            Italy   25085
# 10            Spain   21717
# 63           France   21373
# 126  United Kingdom   18151
# 137         Belgium    6262
# 68             Iran    5391
# 74          Germany    5279
# 154           China    4636
# 135     Netherlands    4068
# 119          Brazil    2906
# 76           Turkey    2376
# 26           Canada    2075
# 101          Sweden    1937
# 85      Switzerland    1509
# 109          Mexico     857
# 87         Portugal     785
# 55          Ireland     769
# 142           India     681
# 38        Indonesia     635
# 80          Ecuador     537
# 147            Peru     530
# 100         Romania     524
# 167          Russia     513
# 97          Austria     510
# 159     Philippines     446
# 9            Poland     426
# 11          Algeria     402
# 23          Denmark     384

# %% [markdown]
# ### CURVAS DE TIEMPO: TOP 30 MUERTOS NORMALIZADOS

# %%
#Lista con los 10 paises con mas contagioados segun porcentaje
top30_norm_lista = top30_norm['Country/Region'].unique()
top30_norm_lista[:10]
# Out:
# array(['San Marino', 'Belgium', 'Spain', 'Andorra', 'Italy', 'France',
#        'United Kingdom', 'Netherlands', 'Sweden', 'Switzerland'],
#       dtype=object)

# %%
#Nombres de las columnas del nuevo dataset, nombre_pais + union de series de tiempo
lista_top30_norm =['Country/Region']
lista_fechas =list(datos_global_deaths.columns)[4:]
for i in range(len(lista_fechas)):
    lista_top30_norm.append(lista_fechas[i])

# %%
#Los datos del TOP30_normalizados se separan en 2 dataframes por facilidades de plot
# full_death_top30_norm10: Primeros 10 paises del TOP30 normalizados
# full_death_top30_norm20: 20 paises restantes del TOP30 normalizados

#Cada dataframe contiene el nombre del pais en la primera columna
# de la columna 2 al 95 son los muertos del 22/1/20 al 22/4/20

full_death_top30_norm10 = pd.DataFrame(columns=lista_top30_norm)
full_death_top30_norm20 = pd.DataFrame(columns=lista_top30_norm)

myset_death10 = set(top30_norm_lista[:10])
myset_death20 = set(top30_norm_lista[10:])
i=0
for name in list(myset_death10):
    full_death_top30_norm10.loc[i,:1] = name
    full_death_top30_norm10.loc[i,1:] = (100*(datos_global_deaths[(datos_global_deaths['Country/Region']==name)].iloc[:,4:]).sum(axis=0))/datos_countriesWorld[(datos_countriesWorld['Country/Region']==name)].iloc[0,6]
    i += 1
for name in list(myset_death20):    
    full_death_top30_norm20.loc[i,:1] = name
    full_death_top30_norm20.loc[i,1:] = (100*(datos_global_deaths[(datos_global_deaths['Country/Region']==name)].iloc[:,4:]).sum(axis=0))/datos_countriesWorld[(datos_countriesWorld['Country/Region']==name)].iloc[0,6]
# 4/7/20           0.00655458   0.116235   0.0127824   0.0196068      0.0101816
# 4/8/20           0.00761928   0.116235   0.0136737   0.0215819      0.0117326
# 4/9/20           0.00879489   0.116235   0.0145712   0.0243085      0.0131878
# 4/10/20          0.00964887   0.116235   0.0152806   0.0290874      0.0148063
# 4/11/20          0.00983742   0.119654   0.0160871    0.032238       0.016321
# 4/12/20           0.0099705   0.119654   0.0166571   0.0346852       0.017537
# 4/13/20           0.0101923   0.119654   0.0171786   0.0376045      0.0187216
# 4/14/20           0.0114567   0.123073   0.0179184   0.0400518      0.0200118
# 4/15/20           0.0133421   0.123073   0.0190705   0.0427784       0.021274
# 4/16/20           0.0147838    0.12991   0.0201741   0.0467961      0.0227012
# 4/17/20           0.0155269   0.133329   0.0210473   0.0497444      0.0241003
# 4/18/20            0.016758   0.133329   0.0219083   0.0525384      0.0255704
# 4/19/20           0.0170796   0.133329   0.0224177   0.0547544      0.0265554
# 4/20/20           0.0175232   0.133329   0.0228239   0.0561515      0.0273061
# 4/21/20            0.019575   0.136747   0.0238245   0.0577894      0.0286722
# 4/22/20           0.0214826   0.136747   0.0246673    0.060333      0.0299476
#
# [92 rows x 10 columns]

# %%
df20 = full_death_top30_norm20.T
header20 = df20.iloc[0]
df20 = df20[1:]
df20.columns = header20

# %% [markdown]
# # ............................................
# #### NORMALIZACIÓN DE DATOS: POR POBLACIÓN

# %%
# Plot del TOP30 normalizado [%], se destacan los primero 10 paises
# %matplotlib notebook
ax = df10.plot(style='*')
df20.plot(ax = ax, style='-')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Muertos [%]')
plt.title('Casos muertos a la fecha, para TOP30 normalizado')
plt.legend(df10.columns)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Plot detallado del anterior, donde se muestran los primeros 10 paises
# %matplotlib notebook
df10.plot(style='.')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Muertos [%]')
plt.title('Top 10 de casos de muertos, para países normalizados')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # ..................................................
# #### NORMALIZACIÓN DE DATOS: ESCALA LOGARÍTMICA

# %%
# %matplotlib notebook
ax = df10.plot(style='*')
df20.plot(ax = ax, style='.')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Muertos [%]')
plt.title('Casos muertos a la fecha, para TOP30 normalizado')
plt.legend(df10.columns)
plt.yscale('log')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
df10.plot(style='.')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Muertos [%]')
plt.title('Top 10 de casos de muertos, para países normalizados')
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### CURVAS DE TIEMPO: TOP 30 MUERTOS NO NORMALIZADOS

# %%
#Caso analogo al anterior, donde se toman los paises del TOP30_NO_normalizados. 
#Sin embargo, para que sean comparables los paises estos deben ser normalizados.
#De este modo, se vuelven a crear los datasets.

# %%
#Lista con los 10 paises con mas contagiados sin normalizar
top30_NOnorm_lista = top30_NO_norm['Country/Region'].unique()
top30_NOnorm_lista[:10]
# Out:
# array(['US', 'Italy', 'Spain', 'France', 'United Kingdom', 'Belgium',
#        'Iran', 'Germany', 'China', 'Netherlands'], dtype=object)

# %%
#Nombres de las columnas del nuevo dataset, nombre_pais + union de series de tiempo
lista_top30_NOnorm =['Country/Region']
lista_fechas =list(datos_global_deaths.columns)[4:]
for i in range(len(lista_fechas)):
    lista_top30_NOnorm.append(lista_fechas[i])

# %%
#Los datos del TOP30_NO_normalizados se separan en 2 dataframes por facilidades de plot
# full_death_top30_norm10: Primeros 10 paises del TOP30 sin normalizar
# full_death_top30_norm20: 20 paises restantes del TOP30 sin normalizar

#Cada dataframe contiene el nombre del pais en la primera columna
# de la columna 2 al 95 son los muertos del 22/1/20 al 22/4/20

full_death_top30_NOnorm10 = pd.DataFrame(columns=lista_top30_NOnorm)
full_death_top30_NOnorm20 = pd.DataFrame(columns=lista_top30_NOnorm)

myset_death10NO = set(top30_NOnorm_lista[:10])
myset_death20NO = set(top30_NOnorm_lista[10:])
i=0
for name in list(myset_death10NO):
    full_death_top30_NOnorm10.loc[i,:1] = name
    full_death_top30_NOnorm10.loc[i,1:] = (100*(datos_global_deaths[(datos_global_deaths['Country/Region']==name)].iloc[:,4:]).sum(axis=0))/datos_countriesWorld[(datos_countriesWorld['Country/Region']==name)].iloc[0,6]
    i += 1
for name in list(myset_death20NO):    
    full_death_top30_NOnorm20.loc[i,:1] = name
    full_death_top30_NOnorm20.loc[i,1:] = (100*(datos_global_deaths[(datos_global_deaths['Country/Region']==name)].iloc[:,4:]).sum(axis=0))/datos_countriesWorld[(datos_countriesWorld['Country/Region']==name)].iloc[0,6]
    i += 1

# %%
#se trasponen los datos para que los ejes coicidan en el plot
df10NO = full_death_top30_NOnorm10.T
header10NO = df10NO.iloc[0]
df10NO = df10NO[1:]
df10NO.columns = header10NO
df10NO
# Out:
# Country/Region Netherlands       Spain       France        Iran      Italy  \
# 1/22/20                  0           0            0           0          0
# 1/23/20                  0           0            0           0          0
# 1/24/20                  0           0            0           0          0
# 1/25/20                  0           0            0           0          0
# 1/26/20                  0           0            0           0          0
# 1/27/20                  0           0            0           0          0
# 1/28/20                  0           0            0           0          0
# 1/29/20                  0           0            0           0          0
# 1/30/20                  0           0            0           0          0
# 1/31/20                  0           0            0           0          0
# 2/1/20                   0           0            0           0          0
# 2/2/20                   0           0            0           0          0
# 2/3/20                   0           0            0           0          0
# 2/4/20                   0           0            0           0          0
# 2/5/20                   0           0            0           0          0
# 2/6/20                   0           0            0           0          0
# 2/7/20                   0           0            0           0          0
# 2/8/20                   0           0            0           0          0
# 2/9/20                   0           0            0           0          0
# 2/10/20                  0           0            0           0          0
# 2/11/20                  0           0            0           0          0
# 2/12/20                  0           0            0           0          0
# 2/13/20                  0           0            0           0          0
# 2/14/20                  0           0            0           0          0
# 2/15/20                  0           0  1.64268e-06           0          0
# 2/16/20                  0           0  1.64268e-06           0          0
# 2/17/20                  0           0  1.64268e-06           0          0
# 2/18/20                  0           0  1.64268e-06           0          0
# 2/5/20                      0
# 2/6/20                      0
# 2/7/20                      0
# 2/8/20                      0
# 2/9/20                      0
# 2/10/20                     0
# 2/11/20                     0
# 2/12/20                     0
# 2/13/20                     0
# 2/14/20                     0
# 2/15/20                     0
# 2/16/20                     0
# 2/17/20                     0
# 2/18/20                     0
# 2/19/20                     0
# 2/20/20                     0
# ...                       ...
# 3/24/20           0.000697914
# 3/25/20           0.000768861
# 3/26/20           0.000956951
# 3/27/20            0.00125559
# 3/28/20            0.00168456
# 3/29/20            0.00203105
# 3/30/20            0.00232803
# 3/31/20             0.0029583
# 4/1/20             0.00388885
# 4/2/20             0.00482765
# 4/3/20             0.00595785
# 4/4/20             0.00712764
# 4/5/20             0.00815553
# 4/6/20              0.0088848
# 4/7/20              0.0101816
# 4/8/20              0.0117326
# 4/9/20              0.0131878
# 4/10/20             0.0148063
# 4/11/20              0.016321
# 4/12/20              0.017537
# 4/13/20             0.0187216
# 4/14/20             0.0200118
# 4/15/20              0.021274
# 4/16/20             0.0227012
# 4/17/20             0.0241003
# 4/18/20             0.0255704
# 4/19/20             0.0265554
# 4/20/20             0.0273061
# 4/21/20             0.0286722
# 4/22/20             0.0299476
#
# [92 rows x 10 columns]

# %%
df20NO = full_death_top30_NOnorm20.T
header20NO = df20NO.iloc[0]
df20NO = df20NO[1:]
df20NO.columns = header20NO

# %% [markdown]
# # ............................................
# #### NORMALIZACIÓN DE DATOS: POR POBLACIÓN

# %%
# Plot del TOP30 sin normalizar, se destacan los primeros 10 paises
# %matplotlib notebook
ax = df10NO.plot(style='*')
df20NO.plot(ax = ax, style='-')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Muertos[%]')
plt.title('Casos muertos a la fecha, para TOP30 sin normalizar')
plt.legend(df10NO.columns)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
df10NO.plot(style='.')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Muertos [%]')
plt.title('Top 10 de casos de muertos, para países sin normalizar')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # ..................................................
# #### NORMALIZACIÓN DE DATOS: ESCALA LOGARÍTMICA

# %%
# %matplotlib notebook
ax = df10NO.plot(style='*')
df20NO.plot(ax = ax, style='.')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Muertos[%]')
plt.title('Casos muertos a la fecha, para TOP30 sin normalizar')
plt.legend(df10NO.columns)
plt.yscale('log')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
df10NO.plot(style='.')
plt.xlabel('Fecha (22/01/2020 - 20/04/2020)')
plt.ylabel('N° Muertos [%]')
plt.title('Top 10 de casos de muertos, para países sin normalizar')
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### COMPARACIÓN DE ATRIBUTOS

# %%
#scatter plots
new2=muertosNormalizados.sort_values('Porcentaje',ascending=False)

# %%
#Scatter plots para confirmados con normalizar
# %matplotlib notebook

#Poblacion
plt.figure(1)
k = 0
for i in new2['Country/Region'].values:
        jei=full_death[(full_death['Country/Region']==i)]['Population'].values
        if(k<=5):
            #print(i)
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'*', label=i)
        else:
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'b.') 
        k += 1
plt.title('Compración de N° de muertos según Población')
plt.xlabel("Población")
plt.ylabel("Casos Muertos[%]")
plt.legend()
plt.show()

#Ingreso Per Capita
plt.figure(2)
k = 0
for i in new2['Country/Region'].values:
        jei=full_death[(full_death['Country/Region']==i)]['GDP ($ per capita)'].values
#        if i=="Chile":
#            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'*', label="Chile")
        if(k<=5):
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'*', label=i)
        else:
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'b.')
        k += 1
plt.title('Comparación de N° de muertos según Ingreso per capita')
plt.xlabel("GPD [USD/capita]")
plt.ylabel("Casos Muertos [%]")
plt.legend()
plt.show()

#Alfabetización
plt.figure(3)
k = 0
for i in new2['Country/Region'].values:
        jei=full_death[(full_death['Country/Region']==i)]['Literacy (%)'].values
        if(k<=5):
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'*', label=i)
        else:
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'b.')
        k += 1
plt.title('Comparación de N° de muertos según Alfabetización')
plt.xlabel("Alfabetización [%]")
plt.ylabel("Casos Muertos [%]")
plt.legend()
plt.show()

#Densidad Poblacional
plt.figure(4)
k=0
for i in new2['Country/Region'].values:
        jei=full_death[(full_death['Country/Region']==i)]['Pop. Density (per sq. mi.)'].values
        if(k<=5):
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'*', label=i)
        else:
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'b.')
        k += 1
plt.title('Comparación de N° de muertos según Densidad Poblacional')
plt.xlabel("Densidad Poblacional [sq. mi]")
plt.ylabel("Casos Muertos [%]")
plt.legend()
plt.show()

#Tasa de Mortalidad
plt.figure(5)
k=0
for i in new2['Country/Region'].values:
        jei=full_death[(full_death['Country/Region']==i)]['Deathrate'].values
        if(k<=5):
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'*', label=i)
        else:
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'b.')
        k += 1
plt.title('Comparación de N° de muertos según Tasa de mortalidad')
plt.xlabel("Tasa Mortalidad [%]")
plt.ylabel("Casos Muertos [%]")
plt.legend()
plt.show()


#Tasa de Natalidad
plt.figure(6)
k=0
for i in new2['Country/Region'].values:
        jei=full_death[(full_death['Country/Region']==i)]['Birthrate'].values
        if(k<=5):
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'*', label=i)
        else:
            plt.plot(jei,float(new2[new2['Country/Region']==i]['Porcentaje']),'b.')
        k += 1
plt.title('Comparación de N° de muertos según Tasa de natalidad')
plt.xlabel("Tasa Natalidad [%]")
plt.ylabel("Casos Muertos [%]")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
